# %% [markdown]
# #DATA VISUALIZATION

# %%
import matplotlib.pyplot as plt

# %%
#Define Dataset
age = [18,20,23,21,25]
salary =[15000,18000,20000,19000,30000]

#adjust figure size
plt.figure(figsize = (5, 3))

#plotting charts ,(marker = s,o,v,<,>) for points , (linestyle = --, __, dashdot, dotted) , (linewidth)
plt.plot(age,salary, marker= 'v', linestyle = 'dashdot', linewidth = 0.8)

#add labels and title, changing its font size and color
plt.xlabel("Age of Employee", fontsize =12 , color = "red")
plt.ylabel("Salary of Employee", fontsize =12, color = "orange")
plt.title('AGE VS SALARY', fontsize =16, color = "blue")

#grid in graph
plt.grid(True)

#show the charts
plt.show()

# %%
#Define Dataset with dic
import pandas as pd

marks={"marks": [20,30,40,50,60]}

var = pd.DataFrame(marks)

#adjust figure size
plt.figure(figsize = (5, 2))

#plotting charts ,(marker = s,o,v,<,>) for points , (linestyle = --, __, dashdot, dotted) , (linewidth)
plt.plot(var["marks"], marker= 's', linestyle = 'dashdot', linewidth = 0.8)

#add labels and title, changing its font size and color
plt.xlabel("", fontsize =12 , color = "red")
plt.ylabel("", fontsize =12, color = "orange")
plt.title('', fontsize =16, color = "blue")

#grid in graph
plt.grid(True)

#show the charts
plt.show()
